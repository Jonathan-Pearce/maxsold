# %%
kagglehub.login()

# %%
import kagglehub
from kagglehub.config import get_kaggle_credentials

username, _ = get_kaggle_credentials()

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter
import os

os.environ['KAGGLE_USERNAME'] = 'pearcej'
os.environ['KAGGLE_KEY'] = 'KGAT_33ccd4a0469ecbe7c9e66b2bd3a8916f'

# Set the path to the file you'd like to load
file_path = "item_enriched_details_20251222.parquet"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "pearcej/raw-maxsold-item-enriched",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# /tmp/ipykernel_126141/3254850175.py:14: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/kagglehub/exceptions.py:66, in kaggle_api_raise_for_status(response, resource_handle)
#      65 try:
# ---> 66     response.raise_for_status()
#      67 except requests.HTTPError as e:
#
# File ~/.local/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://www.kaggle.com/api/v1/datasets/view/pearcej/raw-maxsold-item-enriched
#
# The above exception was the direct cause of the following exception:
#
# ...
